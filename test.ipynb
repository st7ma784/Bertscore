# %%
from HFDataModuleExample import MyDataModule
import torch
datalocation="/data"
datamodule=MyDataModule(Cache_dir=datalocation,batch_size=100)  
datamodule.prepare_data()
# Out:
# Found cached dataset wmt16 (/data/wmt16/de-en/1.0.0/f5dc442f4d1c2cc487cd2d5591af56c03a5f03bb98a3bb92151d015c8c9cb7ad)
# 100%|██████████| 3/3 [00:00<00:00, 38.99it/s]
#   2%|▏         | 797/45489 [00:42<39:30, 18.85it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 5
#       3 datalocation="/data"
#       4 datamodule=MyDataModule(Cache_dir=datalocation,batch_size=100)
# ----> 5 datamodule.prepare_data()
#
# File /data/Bertscore/HFDataModuleExample.py:84, in MyDataModule.prepare_data(self)
#      79 #2014 german to english
#      80 self.dataset = load_dataset("wmt16", "de-en",
#      81                        cache_dir=self.data_dir,
#      82                        streaming=False,
#      83                        )
# ---> 84 self.get_idf_dict(self.dataset['train'])
#
# File /data/Bertscore/HFDataModuleExample.py:187, in MyDataModule.get_idf_dict(self, arr)
#     185         dataloader= torch.utils.data.DataLoader(arr, batch_size=100, shuffle=False, num_workers=4, prefetch_factor=2, pin_memory=True,drop_last=False)
#     186         for a in tqdm(dataloader):
# --> 187             for tokens in self.process(a):
#     188                 idf_count.update(tokens)
#     189 #       idf_count.update(chain.from_iterable(p.map(self.process, arr)))
#
# File /data/Bertscore/HFDataModuleExample.py:158, in MyDataModule.process(self, a)
#     155 def process(self,a):
# --> 158     return chain.from_iterable([ self.batch_encode(a["translation"][key]) for key in a["translation"].keys()])
#
# File /data/Bertscore/HFDataModuleExample.py:158, in <listcomp>(.0)
#     155 def process(self,a):
# --> 158     return chain.from_iterable([ self.batch_encode(a["translation"][key]) for key in a["translation"].keys()])
#
# File /data/Bertscore/HFDataModuleExample.py:99, in MyDataModule.batch_encode(self, sents)
#      97 def batch_encode(self, sents):
#      98     "Encoding as batch based on the self.tokenizer"
# ---> 99     return [self.sent_encode(sent) for sent in sents]
#
# File /data/Bertscore/HFDataModuleExample.py:99, in <listcomp>(.0)
#      97 def batch_encode(self, sents):
#      98     "Encoding as batch based on the self.tokenizer"
# ---> 99     return [self.sent_encode(sent) for sent in sents]
#
# File /data/Bertscore/HFDataModuleExample.py:96, in MyDataModule.sent_encode(self, sent)
#      94     print("here!")
#      95     return self.tokenizer.build_inputs_with_special_tokens([])
# ---> 96 return self.tokenize(sent)
#
# File ~/miniconda3/envs/open-ce/lib/python3.9/site-packages/transformers/tokenization_utils_base.py:2294, in PreTrainedTokenizerBase.encode(self, text, text_pair, add_special_tokens, padding, truncation, max_length, stride, return_tensors, **kwargs)
#    2257 @add_end_docstrings(
#    2258     ENCODE_KWARGS_DOCSTRING,
#    2259     """
#    (...)
#    2277     **kwargs
#    2278 ) -> List[int]:
#    2279     """
#    2280     Converts a string to a sequence of ids (integer), using the tokenizer and vocabulary.
#    2281
#    (...)
#    2292             method).
#    2293     """
# -> 2294     encoded_inputs = self.encode_plus(
#    2295         text,
#    2296         text_pair=text_pair,
#    2297         add_special_tokens=add_special_tokens,
#    2298         padding=padding,
#    2299         truncation=truncation,
#    2300         max_length=max_length,
#    2301         stride=stride,
#    2302         return_tensors=return_tensors,
#    2303         **kwargs,
#    2304     )
#    2306     return encoded_inputs["input_ids"]
#
# File ~/miniconda3/envs/open-ce/lib/python3.9/site-packages/transformers/tokenization_utils_base.py:2702, in PreTrainedTokenizerBase.encode_plus(self, text, text_pair, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    2692 # Backward compatibility for 'truncation_strategy', 'pad_to_max_length'
#    2693 padding_strategy, truncation_strategy, max_length, kwargs = self._get_padding_truncation_strategies(
#    2694     padding=padding,
#    2695     truncation=truncation,
#    (...)
#    2699     **kwargs,
#    2700 )
# -> 2702 return self._encode_plus(
#    2703     text=text,
#    2704     text_pair=text_pair,
#    2705     add_special_tokens=add_special_tokens,
#    2706     padding_strategy=padding_strategy,
#    2707     truncation_strategy=truncation_strategy,
#    2708     max_length=max_length,
#    2709     stride=stride,
#    2710     is_split_into_words=is_split_into_words,
#    2711     pad_to_multiple_of=pad_to_multiple_of,
#    2712     return_tensors=return_tensors,
#    2713     return_token_type_ids=return_token_type_ids,
#    2714     return_attention_mask=return_attention_mask,
#    2715     return_overflowing_tokens=return_overflowing_tokens,
#    2716     return_special_tokens_mask=return_special_tokens_mask,
#    2717     return_offsets_mapping=return_offsets_mapping,
#    2718     return_length=return_length,
#    2719     verbose=verbose,
#    2720     **kwargs,
#    2721 )
#
# File ~/miniconda3/envs/open-ce/lib/python3.9/site-packages/transformers/tokenization_utils.py:649, in PreTrainedTokenizer._encode_plus(self, text, text_pair, add_special_tokens, padding_strategy, truncation_strategy, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#     640 if return_offsets_mapping:
#     641     raise NotImplementedError(
#     642         "return_offset_mapping is not available when using Python tokenizers. "
#     643         "To use this feature, change your tokenizer to one deriving from "
#    (...)
#     646         "https://github.com/huggingface/transformers/pull/2674"
#     647     )
# --> 649 first_ids = get_input_ids(text)
#     650 second_ids = get_input_ids(text_pair) if text_pair is not None else None
#     652 return self.prepare_for_model(
#     653     first_ids,
#     654     pair_ids=second_ids,
#    (...)
#     668     verbose=verbose,
#     669 )
#
# File ~/miniconda3/envs/open-ce/lib/python3.9/site-packages/transformers/tokenization_utils.py:616, in PreTrainedTokenizer._encode_plus.<locals>.get_input_ids(text)
#     614 def get_input_ids(text):
#     615     if isinstance(text, str):
# --> 616         tokens = self.tokenize(text, **kwargs)
#     617         return self.convert_tokens_to_ids(tokens)
#     618     elif isinstance(text, (list, tuple)) and len(text) > 0 and isinstance(text[0], str):
#
# File ~/miniconda3/envs/open-ce/lib/python3.9/site-packages/transformers/tokenization_utils.py:517, in PreTrainedTokenizer.tokenize(self, text, **kwargs)
#     514     text = re.sub(pattern, lambda m: m.groups()[0] or m.groups()[1].lower(), text)
#     516 no_split_token = set(self.unique_no_split_tokens)
# --> 517 tokens = self.tokens_trie.split(text)
#     518 # ["This is something", "<special_token_1>", "  else"]
#     519 for i, token in enumerate(tokens):
#
# File ~/miniconda3/envs/open-ce/lib/python3.9/site-packages/transformers/tokenization_utils.py:145, in Trie.split(self, text)
#     139     continue
#     141 # This will track every state
#     142 # that stop matching, we need to stop tracking them.
#     143 # If we look at "lowball", we're going to match "l" (add it to states), "o", "w", then
#     144 # fail on "b", we need to remove 0 from the valid states.
# --> 145 to_remove = set()
#     146 # Whenever we found a match, we need to drop everything
#     147 # this is a greedy algorithm, it will match on the first found token
#     148 reset = False
#
# KeyboardInterrupt:

# %%
from datasets  import load_dataset

dataset=load_dataset("wmt16", "de-en",
                               cache_dir="/data",
                               streaming=False,)
def find_length(batch):
    print(batch.keys())
    En= batch['translation']["en"]
    length=[len(e) for e in En]
    return {"length":length}
dataset=dataset["train"].map(find_length,batched=True,remove_columns=["translation"])
for i in dataset:
    print(i)
    
lengths=dataset["length"]    
print("Average length of English sentence is ", sum(lengths)/len(lengths))
#plot
import matplotlib.pyplot as plt
plt.hist(lengths, bins=200)
plt.show()
# Out:
# Found cached dataset wmt16 (/data/wmt16/de-en/1.0.0/f5dc442f4d1c2cc487cd2d5591af56c03a5f03bb98a3bb92151d015c8c9cb7ad)
# 100%|██████████| 3/3 [00:00<00:00, 39.53it/s]
#   0%|          | 0/4549 [00:00<?, ?ba/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 10
#       8     length=[len(e) for e in En]
#       9     return {"length":length}
# ---> 10 dataset=dataset["train"].map(find_length,batched=True,remove_columns=["translation"])
#      11 for i in dataset:
#      12     print(i)
#
# File ~/miniconda3/envs/open-ce/lib/python3.9/site-packages/datasets/arrow_dataset.py:2815, in Dataset.map(self, function, with_indices, with_rank, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, load_from_cache_file, cache_file_name, writer_batch_size, features, disable_nullable, fn_kwargs, num_proc, suffix_template, new_fingerprint, desc)
#    2812 disable_tqdm = not logging.is_progress_bar_enabled()
#    2814 if num_proc is None or num_proc == 1:
# -> 2815     return self._map_single(
#    2816         function=function,
#    2817         with_indices=with_indices,
#    2818         with_rank=with_rank,
#    2819         input_columns=input_columns,
#    2820         batched=batched,
#    2821         batch_size=batch_size,
#    2822         drop_last_batch=drop_last_batch,
#    2823         remove_columns=remove_columns,
#    2824         keep_in_memory=keep_in_memory,
#    2825         load_from_cache_file=load_from_cache_file,
#    2826         cache_file_name=cache_file_name,
#    2827         writer_batch_size=writer_batch_size,
#    2828         features=features,
#    2829         disable_nullable=disable_nullable,
#    2830         fn_kwargs=fn_kwargs,
#    2831         new_fingerprint=new_fingerprint,
#    2832         disable_tqdm=disable_tqdm,
#    2833         desc=desc,
#    2834     )
#    2835 else:
#    2837     def format_cache_file_name(cache_file_name, rank):
#
# File ~/miniconda3/envs/open-ce/lib/python3.9/site-packages/datasets/arrow_dataset.py:546, in transmit_tasks.<locals>.wrapper(*args, **kwargs)
#     544     self: "Dataset" = kwargs.pop("self")
#     545 # apply actual function
# --> 546 out: Union["Dataset", "DatasetDict"] = func(self, *args, **kwargs)
#     547 datasets: List["Dataset"] = list(out.values()) if isinstance(out, dict) else [out]
#     548 for dataset in datasets:
#     549     # Remove task templates if a column mapping of the template is no longer valid
#
# File ~/miniconda3/envs/open-ce/lib/python3.9/site-packages/datasets/arrow_dataset.py:513, in transmit_format.<locals>.wrapper(*args, **kwargs)
#     506 self_format = {
#     507     "type": self._format_type,
#     508     "format_kwargs": self._format_kwargs,
#     509     "columns": self._format_columns,
#     510     "output_all_columns": self._output_all_columns,
#     511 }
#     512 # apply actual function
# --> 513 out: Union["Dataset", "DatasetDict"] = func(self, *args, **kwargs)
#     514 datasets: List["Dataset"] = list(out.values()) if isinstance(out, dict) else [out]
#     515 # re-apply format to the output
#
# File ~/miniconda3/envs/open-ce/lib/python3.9/site-packages/datasets/fingerprint.py:480, in fingerprint_transform.<locals>._fingerprint.<locals>.wrapper(*args, **kwargs)
#     476             validate_fingerprint(kwargs[fingerprint_name])
#     478 # Call actual function
# --> 480 out = func(self, *args, **kwargs)
#     482 # Update fingerprint of in-place transforms + update in-place history of transforms
#     484 if inplace:  # update after calling func so that the fingerprint doesn't change if the function fails
#
# File ~/miniconda3/envs/open-ce/lib/python3.9/site-packages/datasets/arrow_dataset.py:3236, in Dataset._map_single(self, function, with_indices, with_rank, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, load_from_cache_file, cache_file_name, writer_batch_size, features, disable_nullable, fn_kwargs, new_fingerprint, rank, offset, disable_tqdm, desc, cache_only)
#    3232 indices = list(
#    3233     range(*(slice(i, i + batch_size).indices(input_dataset.num_rows)))
#    3234 )  # Something simpler?
#    3235 try:
# -> 3236     batch = apply_function_on_filtered_inputs(
#    3237         batch,
#    3238         indices,
#    3239         check_same_num_examples=len(input_dataset.list_indexes()) > 0,
#    3240         offset=offset,
#    3241     )
#    3242 except NumExamplesMismatchError:
#    3243     raise DatasetTransformationNotAllowedError(
#    3244         "Using `.map` in batched mode on a dataset with attached indexes is allowed only if it doesn't create or remove existing examples. You can first run `.drop_index() to remove your index and then re-add it."
#    3245     ) from None
#
# File ~/miniconda3/envs/open-ce/lib/python3.9/site-packages/datasets/arrow_dataset.py:3112, in Dataset._map_single.<locals>.apply_function_on_filtered_inputs(pa_inputs, indices, check_same_num_examples, offset)
#    3110 if with_rank:
#    3111     additional_args += (rank,)
# -> 3112 processed_inputs = function(*fn_args, *additional_args, **fn_kwargs)
#    3113 if isinstance(processed_inputs, LazyDict):
#    3114     processed_inputs = {
#    3115         k: v for k, v in processed_inputs.data.items() if k not in processed_inputs.keys_to_format
#    3116     }
#
# Cell In[9], line 7, in find_length(batch)
#       6 def find_length(batch):
# ----> 7     En= batch['translation']["en"]
#       8     length=[len(e) for e in En]
#       9     return {"length":length}
#
# TypeError: list indices must be integers or slices, not str

# %%
print(datamodule.dataset.keys())
print(datamodule.dataset['train'])

dataloader=datamodule.train_dataloader()
for i in datamodule.dataset['train']:
    print(i)
    break
# Out:
# dict_keys(['train', 'validation', 'test'])
# Dataset({
#     features: ['translation'],
#     num_rows: 4548885
# })
# {'translation': {'de': 'Wiederaufnahme der Sitzungsperiode', 'en': 'Resumption of the session'}}

# %%
datamodule.setup()
dl=datamodule.train_dataloader()
for batch in tqdm(dl):
    print(batch)
# Out:
#   0%|          | 0/4549 [00:00<?, ?ba/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 datamodule.setup()
#       2 dl=datamodule.train_dataloader()
#       3 for batch in tqdm(dl):
#
# File /data/Bertscore/HFDataModuleExample.py:203, in MyDataModule.setup(self, stage)
#     197     self.get_idf_dict(self.dataset['train']['translation']['en'])
#     198 #MAP ITEM -> [{'en' : item.split("|||")[0], 'zh' : item.split("|||")[1]} for item in self.dataset['train']['translation']]
#     199 # reformatted_dataset = self.dataset["train"].map(lambda x: {'en' : x["text"].split("|||")[0], 'de' : x["text"].split("|||")[1]})
#     200 #remove the old "text" column
#     201 # reformatted_dataset.remove_columns("text")
#     202 #tokenize the reformatted dataset
# --> 203 self.train=self.dataset['train'].map(lambda x: self.tokenization(x), batched=True)
#     204 self.val=self.dataset['test'].map(lambda x: self.tokenization(x), batched=True)
#     205 self.test = self.dataset['test'].map(lambda x: self.tokenization(x), batched=True)
#
# File ~/miniconda3/envs/open-ce/lib/python3.9/site-packages/datasets/arrow_dataset.py:2815, in Dataset.map(self, function, with_indices, with_rank, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, load_from_cache_file, cache_file_name, writer_batch_size, features, disable_nullable, fn_kwargs, num_proc, suffix_template, new_fingerprint, desc)
#    2812 disable_tqdm = not logging.is_progress_bar_enabled()
#    2814 if num_proc is None or num_proc == 1:
# -> 2815     return self._map_single(
#    2816         function=function,
#    2817         with_indices=with_indices,
#    2818         with_rank=with_rank,
#    2819         input_columns=input_columns,
#    2820         batched=batched,
#    2821         batch_size=batch_size,
#    2822         drop_last_batch=drop_last_batch,
#    2823         remove_columns=remove_columns,
#    2824         keep_in_memory=keep_in_memory,
#    2825         load_from_cache_file=load_from_cache_file,
#    2826         cache_file_name=cache_file_name,
#    2827         writer_batch_size=writer_batch_size,
#    2828         features=features,
#    2829         disable_nullable=disable_nullable,
#    2830         fn_kwargs=fn_kwargs,
#    2831         new_fingerprint=new_fingerprint,
#    2832         disable_tqdm=disable_tqdm,
#    2833         desc=desc,
#    2834     )
#    2835 else:
#    2837     def format_cache_file_name(cache_file_name, rank):
#
# File ~/miniconda3/envs/open-ce/lib/python3.9/site-packages/datasets/arrow_dataset.py:546, in transmit_tasks.<locals>.wrapper(*args, **kwargs)
#     544     self: "Dataset" = kwargs.pop("self")
#     545 # apply actual function
# --> 546 out: Union["Dataset", "DatasetDict"] = func(self, *args, **kwargs)
#     547 datasets: List["Dataset"] = list(out.values()) if isinstance(out, dict) else [out]
#     548 for dataset in datasets:
#     549     # Remove task templates if a column mapping of the template is no longer valid
#
# File ~/miniconda3/envs/open-ce/lib/python3.9/site-packages/datasets/arrow_dataset.py:513, in transmit_format.<locals>.wrapper(*args, **kwargs)
#     506 self_format = {
#     507     "type": self._format_type,
#     508     "format_kwargs": self._format_kwargs,
#     509     "columns": self._format_columns,
#     510     "output_all_columns": self._output_all_columns,
#     511 }
#     512 # apply actual function
# --> 513 out: Union["Dataset", "DatasetDict"] = func(self, *args, **kwargs)
#     514 datasets: List["Dataset"] = list(out.values()) if isinstance(out, dict) else [out]
#     515 # re-apply format to the output
#
# File ~/miniconda3/envs/open-ce/lib/python3.9/site-packages/datasets/fingerprint.py:480, in fingerprint_transform.<locals>._fingerprint.<locals>.wrapper(*args, **kwargs)
#     476             validate_fingerprint(kwargs[fingerprint_name])
#     478 # Call actual function
# --> 480 out = func(self, *args, **kwargs)
#     482 # Update fingerprint of in-place transforms + update in-place history of transforms
#     484 if inplace:  # update after calling func so that the fingerprint doesn't change if the function fails
#
# File ~/miniconda3/envs/open-ce/lib/python3.9/site-packages/datasets/arrow_dataset.py:3236, in Dataset._map_single(self, function, with_indices, with_rank, input_columns, batched, batch_size, drop_last_batch, remove_columns, keep_in_memory, load_from_cache_file, cache_file_name, writer_batch_size, features, disable_nullable, fn_kwargs, new_fingerprint, rank, offset, disable_tqdm, desc, cache_only)
#    3232 indices = list(
#    3233     range(*(slice(i, i + batch_size).indices(input_dataset.num_rows)))
#    3234 )  # Something simpler?
#    3235 try:
# -> 3236     batch = apply_function_on_filtered_inputs(
#    3237         batch,
#    3238         indices,
#    3239         check_same_num_examples=len(input_dataset.list_indexes()) > 0,
#    3240         offset=offset,
#    3241     )
#    3242 except NumExamplesMismatchError:
#    3243     raise DatasetTransformationNotAllowedError(
#    3244         "Using `.map` in batched mode on a dataset with attached indexes is allowed only if it doesn't create or remove existing examples. You can first run `.drop_index() to remove your index and then re-add it."
#    3245     ) from None
#
# File ~/miniconda3/envs/open-ce/lib/python3.9/site-packages/datasets/arrow_dataset.py:3112, in Dataset._map_single.<locals>.apply_function_on_filtered_inputs(pa_inputs, indices, check_same_num_examples, offset)
#    3110 if with_rank:
#    3111     additional_args += (rank,)
# -> 3112 processed_inputs = function(*fn_args, *additional_args, **fn_kwargs)
#    3113 if isinstance(processed_inputs, LazyDict):
#    3114     processed_inputs = {
#    3115         k: v for k, v in processed_inputs.data.items() if k not in processed_inputs.keys_to_format
#    3116     }
#
# File /data/Bertscore/HFDataModuleExample.py:203, in MyDataModule.setup.<locals>.<lambda>(x)
#     197     self.get_idf_dict(self.dataset['train']['translation']['en'])
#     198 #MAP ITEM -> [{'en' : item.split("|||")[0], 'zh' : item.split("|||")[1]} for item in self.dataset['train']['translation']]
#     199 # reformatted_dataset = self.dataset["train"].map(lambda x: {'en' : x["text"].split("|||")[0], 'de' : x["text"].split("|||")[1]})
#     200 #remove the old "text" column
#     201 # reformatted_dataset.remove_columns("text")
#     202 #tokenize the reformatted dataset
# --> 203 self.train=self.dataset['train'].map(lambda x: self.tokenization(x), batched=True)
#     204 self.val=self.dataset['test'].map(lambda x: self.tokenization(x), batched=True)
#     205 self.test = self.dataset['test'].map(lambda x: self.tokenization(x), batched=True)
#
# File /data/Bertscore/HFDataModuleExample.py:66, in MyDataModule.tokenization(self, sample)
#      64 def tokenization(self,sample):
# ---> 66     return self.collate_idf(sample['translation']['en']),self.collate_idf(sample['translation']["de"])
#
# TypeError: list indices must be integers or slices, not str

# %%
#next lets check some linear sum assignments...
import torch
from lsafunctions import get_all_LSA_fns

lsa_fns=get_all_LSA_fns()

random_input=torch.randn(50,50)

for name,lsa_fn in lsa_fns.items():
    print(name)
    assert lsa_fn(random_input).shape==random_input.shape
    print(sum(lsa_fn(random_input).flatten()))
# Out:
# my function
# tensor(50.)
# recursive fn
# tensor(50.)
# recursive fn2
# tensor(50.)
# recursive fn5
# tensor(50.)
# stock
# tensor(50.)
